# %%
import numpy as np

# %%
import pandas as pd

# %%
notlar = {"Serkan": 50, "Ahmet": 70, "Mehmet": 85}

# %%
pd.Series(notlar)
# Out:
# Serkan    50
# Ahmet     70
# Mehmet    85
# dtype: int64

# %%
names = ["Serkan", "Ahmet", "Mehmet"]

# %%
notlar = [50, 70, 85]

# %%
pd.Series(names)
# Out:
# 0    Serkan
# 1     Ahmet
# 2    Mehmet
# dtype: str

# %%
pd.Series(notlar)
# Out:
# 0    50
# 1    70
# 2    85
# dtype: int64

# %%
pd.Series(names,notlar)
# Out:
# 50    Serkan
# 70     Ahmet
# 85    Mehmet
# dtype: str

# %%
pd.Series(data=notlar,index=names)
# Out:
# Serkan    50
# Ahmet     70
# Mehmet    85
# dtype: int64

# %%
# with numpy

# %%
numpy_array = np.array([50, 40, 30, 20])

# %%
pd.Series(numpy_array)
# Out:
# 0    50
# 1    40
# 2    30
# 3    20
# dtype: int64

# %%
#  arithmetic

# %%
contest_result1 = pd.Series(data=[10,5,100], index=["Serkan","Ahmet","Mehmet"])

# %%
contest_result2 = pd.Series(data=[50,30,15], index=["Serkan","Ahmet","Mehmet"])

# %%
contest_result1
# Out:
# Serkan     10
# Ahmet       5
# Mehmet    100
# dtype: int64

# %%
contest_result2
# Out:
# Serkan    50
# Ahmet     30
# Mehmet    15
# dtype: int64

# %%
contest_result1["Serkan"]
# Out:
# np.int64(10)

# %%
contest_result2["Mehmet"]
# Out:
# np.int64(15)

# %%
final_result = contest_result1 + contest_result2

# %%
final_result
# Out:
# Serkan     60
# Ahmet      35
# Mehmet    115
# dtype: int64

# %%
contest_result1 - contest_result2
# Out:
# Serkan   -40
# Ahmet    -25
# Mehmet    85
# dtype: int64

# %%
contest_result1 * contest_result2
# Out:
# Serkan     500
# Ahmet      150
# Mehmet    1500
# dtype: int64

# %%
contest_result1 / contest_result2
# Out:
# Serkan    0.200000
# Ahmet     0.166667
# Mehmet    6.666667
# dtype: float64

# %%
(contest_result1 + contest_result2) / 2
# Out:
# Serkan    30.0
# Ahmet     17.5
# Mehmet    57.5
# dtype: float64

# %%
new_series1 = pd.Series([25,30,55,70],["a","b","c","d"])

# %%
new_series2 = pd.Series([10,5,25,80],["a","c","g","f"])

# %%
new_series1 + new_series2
# Out:
# a    35.0
# b     NaN
# c    60.0
# d     NaN
# f     NaN
# g     NaN
# dtype: float64
