# %%
import numpy as np

# %%
import pandas as pd

# %%
data = np.random.randn(4,3)

# %%
data
# Out:
# array([[-1.17565288,  1.25985945,  1.3367748 ],
#        [-0.7120347 ,  0.657909  ,  0.38430577],
#        [-1.77417494,  1.78738441,  0.39106521],
#        [-1.40256861,  0.43249799, -0.62445794]])

# %%
data_frame = pd.DataFrame(data)

# %%
data_frame
# Out:
#           0         1         2
# 0 -1.175653  1.259859  1.336775
# 1 -0.712035  0.657909  0.384306
# 2 -1.774175  1.787384  0.391065
# 3 -1.402569  0.432498 -0.624458

# %%
type(data_frame)
# Out:
# pandas.DataFrame

# %%
type(data_frame[0])
# Out:
# pandas.Series

# %%
new_data_frame = pd.DataFrame(data, index = ["Serkan", "Ahmet", "Mısra", "İpek"], columns = ["Age", "Salary", "Seniority"])

# %%
new_data_frame
# Out:
#              Age    Salary  Seniority
# Serkan -1.175653  1.259859   1.336775
# Ahmet  -0.712035  0.657909   0.384306
# Mısra  -1.774175  1.787384   0.391065
# İpek   -1.402569  0.432498  -0.624458

# %%
new_data_frame[["Age","Salary"]]
# Out:
#              Age    Salary
# Serkan -1.175653  1.259859
# Ahmet  -0.712035  0.657909
# Mısra  -1.774175  1.787384
# İpek   -1.402569  0.432498

# %%
new_data_frame.loc["Serkan"]
# Out:
# Age         -1.175653
# Salary       1.259859
# Seniority    1.336775
# Name: Serkan, dtype: float64

# %%
new_data_frame.iloc[2]
# Out:
# Age         -1.774175
# Salary       1.787384
# Seniority    0.391065
# Name: Mısra, dtype: float64

# %%
new_data_frame.iloc[:,1]
# Out:
# Serkan    1.259859
# Ahmet     0.657909
# Mısra     1.787384
# İpek      0.432498
# Name: Salary, dtype: float64

# %%
new_data_frame["Extra"] = 10

# %%
new_data_frame
# Out:
#              Age    Salary  Seniority  Extra
# Serkan -1.175653  1.259859   1.336775     10
# Ahmet  -0.712035  0.657909   0.384306     10
# Mısra  -1.774175  1.787384   0.391065     10
# İpek   -1.402569  0.432498  -0.624458     10

# %%
new_data_frame.drop("Extra", axis = 1 )
# Out:
#              Age    Salary  Seniority
# Serkan -1.175653  1.259859   1.336775
# Ahmet  -0.712035  0.657909   0.384306
# Mısra  -1.774175  1.787384   0.391065
# İpek   -1.402569  0.432498  -0.624458

# %%
new_data_frame
# Out:
#              Age    Salary  Seniority  Extra
# Serkan -1.175653  1.259859   1.336775     10
# Ahmet  -0.712035  0.657909   0.384306     10
# Mısra  -1.774175  1.787384   0.391065     10
# İpek   -1.402569  0.432498  -0.624458     10

# %%
new_data_frame.drop("Extra", axis=1, inplace=True)

# %%
new_data_frame
# Out:
#              Age    Salary  Seniority
# Serkan -1.175653  1.259859   1.336775
# Ahmet  -0.712035  0.657909   0.384306
# Mısra  -1.774175  1.787384   0.391065
# İpek   -1.402569  0.432498  -0.624458

# %%
new_data_frame.drop("Ahmet")
# Out:
#              Age    Salary  Seniority
# Serkan -1.175653  1.259859   1.336775
# Mısra  -1.774175  1.787384   0.391065
# İpek   -1.402569  0.432498  -0.624458

# %%
new_data_frame["Mısra"] = 10

# %%
new_data_frame
# Out:
#              Age    Salary  Seniority  Mısra
# Serkan -1.175653  1.259859   1.336775     10
# Ahmet  -0.712035  0.657909   0.384306     10
# Mısra  -1.774175  1.787384   0.391065     10
# İpek   -1.402569  0.432498  -0.624458     10

# %%
new_data_frame.drop("Mısra")
# Out:
#              Age    Salary  Seniority  Mısra
# Serkan -1.175653  1.259859   1.336775     10
# Ahmet  -0.712035  0.657909   0.384306     10
# İpek   -1.402569  0.432498  -0.624458     10

# %%
new_data_frame.drop("Mısra", axis=1, inplace=True)

# %%
new_data_frame
# Out:
#              Age    Salary  Seniority
# Serkan -1.175653  1.259859   1.336775
# Ahmet  -0.712035  0.657909   0.384306
# Mısra  -1.774175  1.787384   0.391065
# İpek   -1.402569  0.432498  -0.624458

# %%
new_data_frame.loc["İpek"]
# Out:
# Age         -1.402569
# Salary       0.432498
# Seniority   -0.624458
# Name: İpek, dtype: float64

# %%
new_data_frame.loc["İpek"]["Salary"]
# Out:
# np.float64(0.4324979850733336)

# %%
new_data_frame.loc["İpek","Salary"]
# Out:
# np.float64(0.4324979850733336)

# %%
new_data_frame.loc["İpek","Salary"] = 10

# %%
new_data_frame
# Out:
#              Age     Salary  Seniority
# Serkan -1.175653   1.259859   1.336775
# Ahmet  -0.712035   0.657909   0.384306
# Mısra  -1.774175   1.787384   0.391065
# İpek   -1.402569  10.000000  -0.624458

# %%
new_data_frame > 0
# Out:
#           Age  Salary  Seniority
# Serkan  False    True       True
# Ahmet   False    True       True
# Mısra   False    True       True
# İpek    False    True      False

# %%
boolean_frame = new_data_frame > 0

# %%
new_data_frame[boolean_frame]
# Out:
#         Age     Salary  Seniority
# Serkan  NaN   1.259859   1.336775
# Ahmet   NaN   0.657909   0.384306
# Mısra   NaN   1.787384   0.391065
# İpek    NaN  10.000000        NaN

# %%
new_data_frame[new_data_frame > 0]
# Out:
#         Age     Salary  Seniority
# Serkan  NaN   1.259859   1.336775
# Ahmet   NaN   0.657909   0.384306
# Mısra   NaN   1.787384   0.391065
# İpek    NaN  10.000000        NaN

# %%
new_data_frame
# Out:
#              Age     Salary  Seniority
# Serkan -1.175653   1.259859   1.336775
# Ahmet  -0.712035   0.657909   0.384306
# Mısra  -1.774175   1.787384   0.391065
# İpek   -1.402569  10.000000  -0.624458

# %%
new_data_frame[new_data_frame["Salary"] > 1]
# Out:
#              Age     Salary  Seniority
# Serkan -1.175653   1.259859   1.336775
# Mısra  -1.774175   1.787384   0.391065
# İpek   -1.402569  10.000000  -0.624458

# %%
new_data_frame
# Out:
#              Age     Salary  Seniority
# Serkan -1.175653   1.259859   1.336775
# Ahmet  -0.712035   0.657909   0.384306
# Mısra  -1.774175   1.787384   0.391065
# İpek   -1.402569  10.000000  -0.624458

# %%
new_data_frame.reset_index()
# Out:
#     index       Age     Salary  Seniority
# 0  Serkan -1.175653   1.259859   1.336775
# 1   Ahmet -0.712035   0.657909   0.384306
# 2   Mısra -1.774175   1.787384   0.391065
# 3    İpek -1.402569  10.000000  -0.624458

# %%
reset_frame = new_data_frame.reset_index()

# %%
reset_frame
# Out:
#     index       Age     Salary  Seniority
# 0  Serkan -1.175653   1.259859   1.336775
# 1   Ahmet -0.712035   0.657909   0.384306
# 2   Mısra -1.774175   1.787384   0.391065
# 3    İpek -1.402569  10.000000  -0.624458

# %%
new_data_frame
# Out:
#              Age     Salary  Seniority
# Serkan -1.175653   1.259859   1.336775
# Ahmet  -0.712035   0.657909   0.384306
# Mısra  -1.774175   1.787384   0.391065
# İpek   -1.402569  10.000000  -0.624458

# %%
reset_frame.loc[0]
# Out:
# index          Serkan
# Age         -1.175653
# Salary       1.259859
# Seniority    1.336775
# Name: 0, dtype: object

# %%
new_indices = ["Srkn", "Ahmt", "Msr", "İpk"]

# %%
new_data_frame["New_İndex"] = new_indices

# %%
new_data_frame
# Out:
#              Age     Salary  Seniority New_İndex
# Serkan -1.175653   1.259859   1.336775      Srkn
# Ahmet  -0.712035   0.657909   0.384306      Ahmt
# Mısra  -1.774175   1.787384   0.391065       Msr
# İpek   -1.402569  10.000000  -0.624458       İpk

# %%
new_data_frame.set_index("New_İndex", inplace=True)

# %%
new_data_frame
# Out:
#                 Age     Salary  Seniority
# New_İndex
# Srkn      -1.175653   1.259859   1.336775
# Ahmt      -0.712035   0.657909   0.384306
# Msr       -1.774175   1.787384   0.391065
# İpk       -1.402569  10.000000  -0.624458

# %%
new_data_frame.loc["Msr"]
# Out:
# Age         -1.774175
# Salary       1.787384
# Seniority    0.391065
# Name: Msr, dtype: float64

# %%
# Multi İndex

# %%
first_index = ["Simpson", "Simpson", "Simpson", "South Park", "South Park", "South Park"]

# %%
inner_index = ["Homer", "Bart", "Marge", "Cartman", "Kenny", "Kyle"]

# %%
zipped_index = list(zip(first_index,inner_index))

# %%
zipped_index
# Out:
# [('Simpson', 'Homer'),
#  ('Simpson', 'Bart'),
#  ('Simpson', 'Marge'),
#  ('South Park', 'Cartman'),
#  ('South Park', 'Kenny'),
#  ('South Park', 'Kyle')]

# %%
zipped_index = pd.MultiIndex.from_tuples(zipped_index)

# %%
zipped_index
# Out:
# MultiIndex([(   'Simpson',   'Homer'),
#             (   'Simpson',    'Bart'),
#             (   'Simpson',   'Marge'),
#             ('South Park', 'Cartman'),
#             ('South Park',   'Kenny'),
#             ('South Park',    'Kyle')],
#            )

# %%
sample_values = np.ones((6,2))

# %%
big_df = pd.DataFrame(sample_values, index = zipped_index, columns = ["Age", "Salary"])

# %%
big_df
# Out:
#                     Age  Salary
# Simpson    Homer    1.0     1.0
#            Bart     1.0     1.0
#            Marge    1.0     1.0
# South Park Cartman  1.0     1.0
#            Kenny    1.0     1.0
#            Kyle     1.0     1.0

# %%
big_df["Age"]
# Out:
# Simpson     Homer      1.0
#             Bart       1.0
#             Marge      1.0
# South Park  Cartman    1.0
#             Kenny      1.0
#             Kyle       1.0
# Name: Age, dtype: float64

# %%
big_df.loc["Simpson"]
# Out:
#        Age  Salary
# Homer  1.0     1.0
# Bart   1.0     1.0
# Marge  1.0     1.0

# %%
big_df.loc["Simpson"].loc["Homer"]
# Out:
# Age       1.0
# Salary    1.0
# Name: Homer, dtype: float64
